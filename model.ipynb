# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix

# Veri yükleme ve ön işleme
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

class_names = ['uçak', 'otomobil', 'kuş', 'kedi', 'geyik',
               'köpek', 'kurbağa', 'at', 'gemi', 'kamyon']

# Veri artırma
datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    zoom_range=0.2
)
datagen.fit(x_train)

# Geliştirilmiş model
model = models.Sequential([
    layers.Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(32, 32, 3)),
    layers.BatchNormalization(),
    layers.Conv2D(32, (3, 3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.25),

    layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.25),

    layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.25),

    layers.Flatten(),
    layers.Dense(512, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.5),
    layers.Dense(10, activation='softmax')
])

# Model derleme
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Erken durdurma ve öğrenme oranı azaltma
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-5)

# Model eğitimi (veri artırma ile)
history = model.fit(datagen.flow(x_train, y_train, batch_size=64),
                    epochs=50,
                    validation_data=(x_test, y_test),
                    callbacks=[early_stopping, reduce_lr])

# Test doğruluğunu yazdırma
test_kayip, test_dogruluk = model.evaluate(x_test, y_test, verbose=0)
print(f"Test Doğruluğu: {test_dogruluk*100:.2f}%")

# Modeli kaydetme
model.save("cifar10_gelismis_model.h5")
print("Model kaydedildi.")

# Eğitim ve doğrulama doğruluğunu görselleştirme
plt.figure(figsize=(8, 6))
plt.plot(history.history['accuracy'], label='Eğitim Doğruluğu')
plt.plot(history.history['val_accuracy'], label='Doğrulama Doğruluğu')
plt.title('Eğitim ve Doğrulama Doğruluğu')
plt.xlabel('Epoch')
plt.ylabel('Doğruluk')
plt.legend()
plt.grid(True)
plt.show()

# Confusion Matrix
y_pred_probs = model.predict(x_test)
y_pred_classes = np.argmax(y_pred_probs, axis=1)
y_true = np.argmax(y_test, axis=1)

cm = confusion_matrix(y_true, y_pred_classes)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=class_names, yticklabels=class_names)
plt.title("Confusion Matrix")
plt.xlabel("Tahmin Edilen")
plt.ylabel("Gerçek")
plt.show()

# Classification Report
report = classification_report(y_true, y_pred_classes, target_names=class_names)
print("Sınıflandırma Raporu:\n")
print(report)
# Out:
# 2025-05-03 10:25:46.231449: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-05-03 10:25:46.231955: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-05-03 10:25:46.234015: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-05-03 10:25:46.239734: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746257146.250021   12490 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746257146.252943   12490 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1746257146.261535   12490 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1746257146.261557   12490 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1746257146.261558   12490 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1746257146.261559   12490 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-05-03 10:25:46.264465: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Epoch 1/50
# /home/seda-ozkaya/PycharmProjects/Cifar-10/.venv/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2025-05-03 10:25:51.043053: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_UNKNOWN: unknown error
# 2025-05-03 10:25:51.043093: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:178] verbose logging is disabled. Rerun with verbose logging (usually --v=1 or --vmodule=cuda_diagnostics=1) to get more diagnostic output from this module
# 2025-05-03 10:25:51.043100: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:183] retrieving CUDA diagnostic information for host: seda-ozkaya-ABRA-A5-V20-3
# 2025-05-03 10:25:51.043103: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:190] hostname: seda-ozkaya-ABRA-A5-V20-3
# 2025-05-03 10:25:51.043334: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:197] libcuda reported version is: 550.120.0
# 2025-05-03 10:25:51.043360: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:201] kernel reported version is: 550.120.0
# 2025-05-03 10:25:51.043362: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:291] kernel version seems to match DSO: 550.120.0
# /home/seda-ozkaya/PycharmProjects/Cifar-10/.venv/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 95s 118ms/step - accuracy: 0.3340 - loss: 2.1337 - val_accuracy: 0.4913 - val_loss: 1.5813 - learning_rate: 0.0010
# Epoch 2/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 77s 99ms/step - accuracy: 0.5235 - loss: 1.3235 - val_accuracy: 0.5744 - val_loss: 1.2903 - learning_rate: 0.0010
# Epoch 3/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 57s 72ms/step - accuracy: 0.6063 - loss: 1.1007 - val_accuracy: 0.6756 - val_loss: 0.9637 - learning_rate: 0.0010
# Epoch 4/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 55s 71ms/step - accuracy: 0.6505 - loss: 0.9927 - val_accuracy: 0.6837 - val_loss: 0.9445 - learning_rate: 0.0010
# Epoch 5/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 53s 67ms/step - accuracy: 0.6813 - loss: 0.9168 - val_accuracy: 0.7217 - val_loss: 0.8377 - learning_rate: 0.0010
# Epoch 6/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 54s 69ms/step - accuracy: 0.7022 - loss: 0.8545 - val_accuracy: 0.7278 - val_loss: 0.7855 - learning_rate: 0.0010
# Epoch 7/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 54s 69ms/step - accuracy: 0.7162 - loss: 0.8094 - val_accuracy: 0.7712 - val_loss: 0.6614 - learning_rate: 0.0010
# Epoch 8/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 56s 72ms/step - accuracy: 0.7284 - loss: 0.7755 - val_accuracy: 0.7602 - val_loss: 0.7048 - learning_rate: 0.0010
# Epoch 9/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 52s 66ms/step - accuracy: 0.7419 - loss: 0.7402 - val_accuracy: 0.7874 - val_loss: 0.6185 - learning_rate: 0.0010
# Epoch 10/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 53s 67ms/step - accuracy: 0.7532 - loss: 0.7130 - val_accuracy: 0.7769 - val_loss: 0.6607 - learning_rate: 0.0010
# Epoch 11/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 54s 69ms/step - accuracy: 0.7640 - loss: 0.6827 - val_accuracy: 0.7543 - val_loss: 0.7330 - learning_rate: 0.0010
# Epoch 12/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 54s 68ms/step - accuracy: 0.7707 - loss: 0.6638 - val_accuracy: 0.7654 - val_loss: 0.6880 - learning_rate: 0.0010
# Epoch 13/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 53s 68ms/step - accuracy: 0.7791 - loss: 0.6376 - val_accuracy: 0.8076 - val_loss: 0.5912 - learning_rate: 0.0010
# Epoch 14/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 51s 65ms/step - accuracy: 0.7860 - loss: 0.6246 - val_accuracy: 0.8150 - val_loss: 0.5507 - learning_rate: 0.0010
# Epoch 15/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 54s 69ms/step - accuracy: 0.7872 - loss: 0.6089 - val_accuracy: 0.8193 - val_loss: 0.5358 - learning_rate: 0.0010
# Epoch 16/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 55s 70ms/step - accuracy: 0.7938 - loss: 0.5952 - val_accuracy: 0.8054 - val_loss: 0.5926 - learning_rate: 0.0010
# Epoch 17/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 56s 72ms/step - accuracy: 0.7999 - loss: 0.5780 - val_accuracy: 0.8316 - val_loss: 0.5012 - learning_rate: 0.0010
# Epoch 18/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 57s 73ms/step - accuracy: 0.8004 - loss: 0.5759 - val_accuracy: 0.8288 - val_loss: 0.5052 - learning_rate: 0.0010
# Epoch 19/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 57s 73ms/step - accuracy: 0.8122 - loss: 0.5454 - val_accuracy: 0.8343 - val_loss: 0.4989 - learning_rate: 0.0010
# Epoch 20/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 52s 66ms/step - accuracy: 0.8104 - loss: 0.5489 - val_accuracy: 0.8269 - val_loss: 0.5190 - learning_rate: 0.0010
# Epoch 21/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 49s 63ms/step - accuracy: 0.8175 - loss: 0.5323 - val_accuracy: 0.8196 - val_loss: 0.5612 - learning_rate: 0.0010
# Epoch 22/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 57s 72ms/step - accuracy: 0.8168 - loss: 0.5370 - val_accuracy: 0.8389 - val_loss: 0.4780 - learning_rate: 0.0010
# Epoch 23/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 55s 70ms/step - accuracy: 0.8225 - loss: 0.5141 - val_accuracy: 0.8204 - val_loss: 0.5605 - learning_rate: 0.0010
# Epoch 24/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 60s 77ms/step - accuracy: 0.8205 - loss: 0.5174 - val_accuracy: 0.8206 - val_loss: 0.5648 - learning_rate: 0.0010
# Epoch 25/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 60s 76ms/step - accuracy: 0.8216 - loss: 0.5091 - val_accuracy: 0.8419 - val_loss: 0.4747 - learning_rate: 0.0010
# Epoch 26/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 58s 74ms/step - accuracy: 0.8251 - loss: 0.5024 - val_accuracy: 0.8131 - val_loss: 0.5637 - learning_rate: 0.0010
# Epoch 27/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 54s 69ms/step - accuracy: 0.8284 - loss: 0.4954 - val_accuracy: 0.8473 - val_loss: 0.4541 - learning_rate: 0.0010
# Epoch 28/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 55s 70ms/step - accuracy: 0.8300 - loss: 0.4921 - val_accuracy: 0.8581 - val_loss: 0.4219 - learning_rate: 0.0010
# Epoch 29/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 54s 70ms/step - accuracy: 0.8315 - loss: 0.4875 - val_accuracy: 0.8421 - val_loss: 0.4654 - learning_rate: 0.0010
# Epoch 30/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 54s 69ms/step - accuracy: 0.8573 - loss: 0.4079 - val_accuracy: 0.8705 - val_loss: 0.3875 - learning_rate: 2.0000e-04
# Epoch 36/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 52s 67ms/step - accuracy: 0.8611 - loss: 0.4053 - val_accuracy: 0.8727 - val_loss: 0.3866 - learning_rate: 2.0000e-04
# Epoch 37/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 51s 65ms/step - accuracy: 0.8620 - loss: 0.3990 - val_accuracy: 0.8804 - val_loss: 0.3549 - learning_rate: 2.0000e-04
# Epoch 38/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 49s 63ms/step - accuracy: 0.8659 - loss: 0.3862 - val_accuracy: 0.8754 - val_loss: 0.3750 - learning_rate: 2.0000e-04
# Epoch 39/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 58s 74ms/step - accuracy: 0.8682 - loss: 0.3794 - val_accuracy: 0.8798 - val_loss: 0.3557 - learning_rate: 2.0000e-04
# Epoch 46/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 50s 64ms/step - accuracy: 0.8701 - loss: 0.3723 - val_accuracy: 0.8756 - val_loss: 0.3728 - learning_rate: 2.0000e-04
# Epoch 47/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 58s 74ms/step - accuracy: 0.8380 - loss: 0.4770 - val_accuracy: 0.8515 - val_loss: 0.4351 - learning_rate: 0.0010
# Epoch 31/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 54s 69ms/step - accuracy: 0.8344 - loss: 0.4739 - val_accuracy: 0.8611 - val_loss: 0.4284 - learning_rate: 0.0010
# Epoch 32/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 54s 69ms/step - accuracy: 0.8390 - loss: 0.4651 - val_accuracy: 0.8442 - val_loss: 0.4717 - learning_rate: 0.0010
# Epoch 33/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 55s 71ms/step - accuracy: 0.8411 - loss: 0.4636 - val_accuracy: 0.8567 - val_loss: 0.4262 - learning_rate: 0.0010
# Epoch 34/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 56s 72ms/step - accuracy: 0.8503 - loss: 0.4258 - val_accuracy: 0.8736 - val_loss: 0.3755 - learning_rate: 2.0000e-04
# Epoch 35/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 53s 67ms/step - accuracy: 0.8639 - loss: 0.3898 - val_accuracy: 0.8781 - val_loss: 0.3597 - learning_rate: 2.0000e-04
# Epoch 40/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 53s 68ms/step - accuracy: 0.8679 - loss: 0.3821 - val_accuracy: 0.8764 - val_loss: 0.3699 - learning_rate: 2.0000e-04
# Epoch 41/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 51s 65ms/step - accuracy: 0.8643 - loss: 0.3892 - val_accuracy: 0.8819 - val_loss: 0.3526 - learning_rate: 2.0000e-04
# Epoch 42/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 54s 69ms/step - accuracy: 0.8649 - loss: 0.3873 - val_accuracy: 0.8793 - val_loss: 0.3612 - learning_rate: 2.0000e-04
# Epoch 43/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 55s 70ms/step - accuracy: 0.8703 - loss: 0.3753 - val_accuracy: 0.8795 - val_loss: 0.3560 - learning_rate: 2.0000e-04
# Epoch 44/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 60s 76ms/step - accuracy: 0.8683 - loss: 0.3788 - val_accuracy: 0.8754 - val_loss: 0.3811 - learning_rate: 2.0000e-04
# Epoch 45/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 55s 70ms/step - accuracy: 0.8766 - loss: 0.3551 - val_accuracy: 0.8825 - val_loss: 0.3514 - learning_rate: 4.0000e-05
# Epoch 48/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 52s 66ms/step - accuracy: 0.8735 - loss: 0.3612 - val_accuracy: 0.8813 - val_loss: 0.3502 - learning_rate: 4.0000e-05
# Epoch 49/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 51s 65ms/step - accuracy: 0.8720 - loss: 0.3635 - val_accuracy: 0.8838 - val_loss: 0.3491 - learning_rate: 4.0000e-05
# Epoch 50/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 60s 76ms/step - accuracy: 0.8721 - loss: 0.3647 - val_accuracy: 0.8830 - val_loss: 0.3544 - learning_rate: 4.0000e-05
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Test Doğruluğu: 88.38%
# Model kaydedildi.
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 27ms/step
# Sınıflandırma Raporu:
#
#               precision    recall  f1-score   support
#
#         uçak       0.93      0.88      0.90      1000
#     otomobil       0.94      0.95      0.95      1000
#          kuş       0.87      0.83      0.85      1000
#         kedi       0.84      0.70      0.76      1000
#        geyik       0.87      0.89      0.88      1000
#        köpek       0.87      0.79      0.83      1000
#      kurbağa       0.79      0.96      0.87      1000
#           at       0.92      0.93      0.92      1000
#         gemi       0.94      0.94      0.94      1000
#       kamyon       0.90      0.96      0.93      1000
#
#     accuracy                           0.88     10000
#    macro avg       0.88      0.88      0.88     10000
# weighted avg       0.88      0.88      0.88     10000
